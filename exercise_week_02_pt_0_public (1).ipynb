# %% [markdown]
# # EEN065 - Applied object-oriented programming
#
# Teacher: Seyed Morteza Ahmadian
#
# Examiners: Paolo Monti and Carlos Natalino Da Silva
#
# TAs: Kiarash Rezaei and Jayadev Naram
#
# [canvas course page](https://chalmers.instructure.com/courses/39015)
#
# [Course channel on Chalmers Play](https://play.chalmers.se/channel/EEN060_EEN065_Applied_object-oriented_programming/300149)
#
# Before you turn this exercise notebook in, make sure everything runs as expected.
# First, **restart the kernel** and then **run all cells**.
# Then check that all tests run correctly.
# Note that if one of the problems presents an error, the following ones **will not** be tested.
#
# In case of discrepancies between the problem statement and the tests, you should solve it with the tests in mind.
#
# There are four types of cells:
# 1. *solution cells:* These are the cells where you write your answer, or modify the existing code to solve the problem.
# 2. *debug cells:* These cells are where you test your solution while developing it. You can either uncomment the indicated lines of code to test your solution once it is complete, or keep the lines commented and write your own test code. You may modify this cell as needed while developing your solution, but make sure it does not introduce errors when you run all cells.
# 3. *test cells:* These cells are used to test whether your solution is correct. If the tests run correctly, you should see a message `tests passed`; otherwise, you should see an error message.
# 4. *code quality tests:* These cells test whether your solution adheres to the code quality rules of the course.
#
# The code quality tests require you to be connected to the Chalmers network, either through Eduroam or through the VPN.
# You can find more information [here](https://chalmers.topdesk.net/tas/public/ssp/content/search?q=KB+1678).
#
# **Delete** the line `raise NotImplementedError()` from the problems that you solve.
#
# **Do not delete or add any cell in this file.** All cells that you need are already in place.
#
# If you want to execute a cell, select the cell and press **CTRL+Enter** (in Windows) or **CMD+Enter** (in macOS) or click on the **Run cell** button.

# %% [markdown]
# # Exercises Week 1 - Part 0
#
# ## Note that the grade for this exercise does not count towards your final grade.

# %%
# %load_ext autoreload
import os

# getting latest version of utils.py
# import requests
# response = requests.get("https://raw.githubusercontent.com/carlosnatalino/programming-assignments/refs/heads/main/utils.py")
# with open("utils.py", "wb") as f:
#     f.write(response.content)

if not os.path.exists("utils.py"):
    raise ValueError("It seems this file is in the wrong folder. "
          "Make sure to place it in the `programming-assignments` folder/project.")

# check if this file is within the same folder as the `utils.py` file.
try:
    from utils import export_cell_content
except:
    import sys
    raise ValueError("Did you select the right kernel that starts with venv?")

filename = "exercise_week_02_pt_0_public (1).ipynb"  # put the name of the file here, e.g. "exercise_week_02_pt_0_public.ipynb"
assert filename != None, "The file name must be set."
if not os.path.exists(filename):
    raise ValueError(f"The value of the `filename` variable is wrong. \
The file `{filename}` does not exist. Write the correct name of this file!")

os.environ["NOTEBOOK_NAME"] = os.path.join(os.getcwd(), filename)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Problem 1
#
# Create a Python function called `calculate_addition` that receives two positive integers $a$ and $b$ and returns the sum $a+b$.

# %% [markdown]
# ```
# # write here your pseudocode (not graded)
#
# # * pseudocode is necessary when asking for help during the lab
# ```

# %%
# solution cell
def calculate_addition(a: int, b: int) -> int:
    return a + b

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-1", "calculate_addition_solution.py")
from calculate_addition_solution import calculate_addition


a = 7
b = 2
c = calculate_addition(a, b)
print(f"The sum of a = {a} and b = {b} is {c}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 09:28:38.032133 (1 minutes ago)
# The sum of a = 7 and b = 2 is 9
# Execution finished ✓

# %%
# test cell
def test_calculate_addition() -> None:
    try:
        import calculate_addition_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from calculate_addition_solution import calculate_addition
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [((2, 4), 6), ((3, 9), 12), ((7, 2), 9)]

    for _in, _out in test_cases:
        _res = calculate_addition(*_in)
        assert _res == _out, f"The function with input `{_in}` should return the value \
    `{_out}` of type `{type(_out)}`\n but returned the value `{_res}` of type `{type(_res)}`."

# %%
# validate the solution
solution_file = "calculate_addition_solution.py"
test_file = "test_calculate_addition.py"
export_cell_content("solution-1", solution_file)
export_cell_content("tests-1", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 09:28:38.032133 (1 minutes ago)
# Latest saved date of the file: 2026-03-31 09:28:38.032133 (1 minutes ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
# 1 passed in 0.09s
#
#
# ############################################# coverage #############################################
# Name                             Stmts   Miss Branch BrPart  Cover   Missing
# ----------------------------------------------------------------------------
# calculate_addition_solution.py       2      0      0      0   100%
# ----------------------------------------------------------------------------
# TOTAL                                2      0      0      0   100%
# coverage True
#
#
# ############################################## flake8 ##############################################
# 0
# flake8 True
#
#
# ############################################## pylint ##############################################
#
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)
#
# pylint True
#
#
# ############################################### mypy ###############################################
# Success: no issues found in 1 source file
# mypy True
#
#
# ############################################## isort ###############################################
# isort True
#
#
# ############################################## result ##############################################
#  tests passed ✓

# %% [markdown]
# ## Problem 2
#
# Create a Python function called `calculate_subtraction` that receives two positive integers $a$ and $b$ and returns the difference $a-b$.

# %% [markdown]
# ```
# # write here your pseudocode (not graded)
#
# # * pseudocode is necessary when asking for help during the lab
# ```

# %%
# solution cell
def calculate_subtraction(a: int, b: int) -> int:
    return a - b

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-2", "calculate_subtraction_solution.py")
from calculate_subtraction_solution import calculate_subtraction


a = 7
b = 2
c = calculate_subtraction(a, b)
print(f"The subtraction between a = {a} and b = {b} is {c}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 09:28:38.032133 (1 minutes ago)
# The subtraction between a = 7 and b = 2 is 5
# Execution finished ✓

# %%
# test cell
def test_calculate_subtraction() -> None:
    try:
        import calculate_subtraction_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from calculate_subtraction_solution import calculate_subtraction
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [((2, 4), -2), ((3, 9), -6), ((7, 2), 5)]

    for _in, _out in test_cases:
        _res = calculate_subtraction(*_in)
        assert _res == _out, f"The function with input `{_in}` should return the value \
    `{_out}` of type `{type(_out)}`\n but returned the value `{_res}` of type `{type(_res)}`."

# %%
# validate the solution
solution_file = "calculate_subtraction_solution.py"
test_file = "test_calculate_subtraction.py"
export_cell_content("solution-2", solution_file)
export_cell_content("tests-2", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 09:28:38.032133 (1 minutes ago)
# Latest saved date of the file: 2026-03-31 09:28:38.032133 (1 minutes ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
# 1 passed in 0.07s
#
#
# ############################################# coverage #############################################
# Name                                Stmts   Miss Branch BrPart  Cover   Missing
# -------------------------------------------------------------------------------
# calculate_subtraction_solution.py       2      0      0      0   100%
# -------------------------------------------------------------------------------
# TOTAL                                   2      0      0      0   100%
# coverage True
#
#
# ############################################## flake8 ##############################################
# 0
# flake8 True
#
#
# ############################################## pylint ##############################################
#
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)
#
# pylint True
#
#
# ############################################### mypy ###############################################
# Success: no issues found in 1 source file
# mypy True
#
#
# ############################################## isort ###############################################
# isort True
#
#
# ############################################## result ##############################################
#  tests passed ✓

# %% [markdown]
# ## Problem 3
#
# Create a Python function called `calculate_product` that receives two positive integers $a$ and $b$ and returns the product $ab$.

# %% [markdown]
# ```
# # write here your pseudocode (not graded)
#
# # * pseudocode is necessary when asking for help during the lab
# ```

# %%
# solution cell
def calculate_product(a: int, b: int) -> int:
    return a * b

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-3", "calculate_product_solution.py")
from calculate_product_solution import calculate_product


a = 7
b = 2
c = calculate_product(a, b)
print(f"The multiplication of a = {a} and b = {b} is {c}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 09:31:13.515153 (3 seconds ago)
# The multiplication of a = 7 and b = 2 is 14
# Execution finished ✓

# %%
# test cell
def test_calculate_product() -> None:
    try:
        import calculate_product_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from calculate_product_solution import calculate_product
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [((2, 4), 8), ((3, 9), 27), ((7, 2), 14)]

    for _in, _out in test_cases:
        _res = calculate_product(*_in)
        assert _res == _out, f"The function with input `{_in}` should return the value \
    `{_out}` of type `{type(_out)}`\n but returned the value `{_res}` of type `{type(_res)}`."

# %%
# validate the solution
solution_file = "calculate_product_solution.py"
test_file = "test_calculate_product.py"
export_cell_content("solution-3", solution_file)
export_cell_content("tests-3", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 09:31:13.515153 (9 seconds ago)
# Latest saved date of the file: 2026-03-31 09:31:13.515153 (9 seconds ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
#
# ############################################# coverage #############################################
#
# 1 passed in 0.05s
# Name                            Stmts   Miss Branch BrPart  Cover   Missing
# ---------------------------------------------------------------------------
# calculate_product_solution.py       2      0      0      0   100%
# ---------------------------------------------------------------------------
# TOTAL                               2      0      0      0   100%
# coverage True
#
#
# ############################################## flake8 ##############################################
# 0
# flake8 True
#
#
# ############################################## pylint ##############################################
#
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)
#
# pylint True
#
#
# ############################################### mypy ###############################################
# Success: no issues found in 1 source file
# mypy True
#
#
# ############################################## isort ###############################################
# isort True
#
#
# ############################################## result ##############################################
#  tests passed ✓

# %% [markdown]
# ## Problem 4
#
# Create a Python function called `calculate_division` that receives two positive integers $a$ and $b$ and returns the quotient $a/b$.

# %% [markdown]
# ```
# # write here your pseudocode (not graded)
#
# # * pseudocode is necessary when asking for help during the lab
# ```

# %%
# solution cell
def calculate_division(a: int, b: int) -> int | float:
    result = a / b
    return result

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-4", "calculate_division_solution.py")
from calculate_division_solution import calculate_division


a = 7
b = 2
c = calculate_division(a, b)
print(f"The division of a = {a} and b = {b} is {c}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 09:38:02.232442 (2 seconds ago)
# The division of a = 7 and b = 2 is 3.5
# Execution finished ✓

# %%
# test cell
def test_calculate_division() -> None:
    try:
        import calculate_division_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from calculate_division_solution import calculate_division
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [((2, 4), 0.5), ((3, 9), 0.3333333333333333), ((7, 2), 3.5)]

    for _in, _out in test_cases:
        _res = calculate_division(*_in)
        assert _res == _out, f"The function with input `{_in}` should return the value \
    `{_out}` of type `{type(_out)}`\n but returned the value `{_res}` of type `{type(_res)}`."

# %%
# validate the solution
solution_file = "calculate_division_solution.py"
test_file = "test_calculate_division.py"
export_cell_content("solution-4", solution_file)
export_cell_content("tests-4", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 09:38:02.232442 (14 seconds ago)
# Latest saved date of the file: 2026-03-31 09:38:02.232442 (14 seconds ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
# 1 passed in 0.05s
#
#
# ############################################# coverage #############################################
# Name                             Stmts   Miss Branch BrPart  Cover   Missingcoverage True
#
#
# ############################################## flake8 ##############################################
#
# ----------------------------------------------------------------------------
# calculate_division_solution.py       3      0      0      0   100%
# ----------------------------------------------------------------------------
# TOTAL                                3      0      0      0   100%
# 0
# flake8 True
#
#
# ############################################## pylint ##############################################
#
# ------------------------------------
# Your code has been rated at 10.00/10
#
# pylint True
#
#
# ############################################### mypy ###############################################
# Success: no issues found in 1 source file
# mypy True
#
#
# ############################################## isort ###############################################
# isort True
#
#
# ############################################## result ##############################################
#  tests passed ✓
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
