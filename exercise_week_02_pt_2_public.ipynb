# %% [markdown]
# # EEN060 - Applied object-oriented programming
#
# Teacher: Seyed Morteza Ahmadian
#
# Examiners: Paolo Monti and Carlos Natalino Da Silva
#
# TAs: Kiarash Rezaei and Jayadev Naram
#
# [canvas course page](https://chalmers.instructure.com/courses/39015)
#
# [Course channel on Chalmers Play](https://play.chalmers.se/channel/EEN060_EEN065_Applied_object-oriented_programming/300149)
#
# Before you turn this exercise notebook in, make sure everything runs as expected.
# First, **restart the kernel** and then **run all cells**.
# Then check that all tests run correctly.
# Note that if one of the problems presents an error, the following ones **will not** be tested.
#
# In case of discrepancies between the problem statement and the tests, you should solve it with the tests in mind.
#
# There are four types of cells:
# 1. *solution cells:* These are the cells where you write your answer, or modify the existing code to solve the problem.
# 2. *debug cells:* These cells are where you test your solution while developing it. You can either uncomment the indicated lines of code to test your solution once it is complete, or keep the lines commented and write your own test code. You may modify this cell as needed while developing your solution, but make sure it does not introduce errors when you run all cells.
# 3. *test cells:* These cells are used to test whether your solution is correct. If the tests run correctly, you should see a message `tests passed`; otherwise, you should see an error message.
# 4. *code quality tests:* These cells test whether your solution adheres to the code quality rules of the course.
#
# The code quality tests require you to be connected to the Chalmers network, either through Eduroam or through the VPN.
# You can find more information [here](https://chalmers.topdesk.net/tas/public/ssp/content/search?q=KB+1678).
#
# **Delete** the line `raise NotImplementedError()` from the problems that you solve.
#
# **Do not delete or add any cell in this file.** All cells that you need are already in place.
#
# If you want to execute a cell, select the cell and press **CTRL+Enter** (in Windows) or **CMD+Enter** (in macOS) or click on the **Run cell** button.

# %% [markdown]
# # Exercises Week 2 - Part 2

# %%
# %load_ext autoreload
import os

# getting latest version of utils.py
# import requests
# response = requests.get("https://raw.githubusercontent.com/carlosnatalino/programming-assignments/refs/heads/main/utils.py")
# with open("utils.py", "wb") as f:
#     f.write(response.content)

if not os.path.exists("utils.py"):
    raise ValueError("It seems this file is in the wrong folder. "
          "Make sure to place it in the `programming-assignments` folder/project.")

# check if this file is within the same folder as the `utils.py` file.
try:
    from utils import export_cell_content
except:
    import sys
    raise ValueError("Did you select the right kernel that starts with venv?")

filename = "exercise_week_02_pt_2_public.ipynb"  # put the name of the file here, e.g. "exercise_week_02_pt_2_public.ipynb"
assert filename != None, "The file name must be set."
if not os.path.exists(filename):
    raise ValueError(f"The value of the `filename` variable is wrong. \
The file `{filename}` does not exist. Write the correct name of this file!")

os.environ["NOTEBOOK_NAME"] = os.path.join(os.getcwd(), filename)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Problem 5
#
# Create a Python function called `int_from_text` that receives a string `text` and returns the integer value represented by the string.
#
# Assume that `text` is always a valid integer representation (e.g., `"10"`, `"-3"`, `"+7"`).

# %%
# solution cell
def int_from_text(text: str) -> int:
    return int(text)

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-1", "to_int_or_none_solution.py")
from to_int_or_none_solution import int_from_text

a = int_from_text("123")
print(f"a is {a} and is of type {type(a)}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 11:14:23.157993 (2 seconds ago)
# a is 123 and is of type <class 'int'>
# Execution finished ✓

# %%
# test cell
def test_int_from_text() -> None:
    try:
        import int_from_text_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from int_from_text_solution import int_from_text
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [
        (("10",), 10),
        (("-3",), -3),
        (("+7",), 7),
        (("0",), 0),
    ]

    for _in, _out in test_cases:
        _res = int_from_text(*_in)
        assert _res == _out, f"The function with input `{_in}` should return the value \
    `{_out}` of type `{type(_out)}`\n but returned the value `{_res}` of type `{type(_res)}`."

# %%
# validate the solution
solution_file = "int_from_text_solution.py"
test_file = "test_int_from_text.py"
export_cell_content("solution-1", solution_file)
export_cell_content("tests-1", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 11:14:23.157993 (7 seconds ago)
# Latest saved date of the file: 2026-03-31 11:14:23.157993 (7 seconds ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
# 1 passed in 0.09s
#
#
# ############################################# coverage #############################################
# Name                        Stmts   Miss Branch BrPart  Cover   Missing
# -----------------------------------------------------------------------
# int_from_text_solution.py       2      0      0      0   100%
# -----------------------------------------------------------------------
# TOTAL                           2      0      0      0   100%
# coverage True
#
#
# ############################################## flake8 ##############################################
# 0
# flake8 True
#
#
# ...

# %% [markdown]
# ## Problem 6
#
# Create a Python function called `float_from_text` that receives a string `text` and returns the floating-point value represented by the string.
#
# Assume that `text` is always a valid float representation (e.g., `"3.14"`, `"0.0"`, `"7"`).

# %%
# solution cell
def float_from_text(text: str) -> float:
    return float(text)

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-2", "float_from_text_solution.py")
from float_from_text_solution import float_from_text

a = float_from_text("3.14")
print(f"a is {a} and is of type {type(a)}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 11:18:39.008676 (4 seconds ago)
# a is 3.14 and is of type <class 'str'>
# Execution finished ✓

# %%
# test cell
def test_float_from_text() -> None:
    try:
        import float_from_text_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from float_from_text_solution import float_from_text
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [
        (("3.14",), 3.14),
        (("0.0",), 0.0),
        (("7",), 7.0),
    ]

    for _in, _out in test_cases:
        _res = float_from_text(*_in)
        assert _res == _out

# %%
# validate the solution
solution_file = "float_from_text_solution.py"
test_file = "test_float_from_text.py"
export_cell_content("solution-2", solution_file)
export_cell_content("tests-2", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 11:18:39.008676 (9 seconds ago)
# Latest saved date of the file: 2026-03-31 11:18:39.008676 (9 seconds ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
# 1 passed in 0.06s
#
#
# ############################################# coverage #############################################
# Name                          Stmts   Miss Branch BrPart  Cover   Missingcoverage True
#
#
# ############################################## flake8 ##############################################
#
# -------------------------------------------------------------------------
# float_from_text_solution.py       2      0      0      0   100%
# -------------------------------------------------------------------------
# TOTAL                             2      0      0      0   100%
# 0flake8 True
#
#
# ...

# %% [markdown]
# ## Problem 7
#
# Create a Python function called `number_to_string` that receives a value `x` that can be an `int` or a `float`
# and returns its string representation.
#
# Use a type hint that allows both types using the pipe character `|`.

# %%
# solution cell
def number_to_string(x: int | float) -> str:
    return str(x)

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-3", "number_to_string_solution.py")
from number_to_string_solution import number_to_string


x = 123
c = number_to_string(x)
print(f"The string representation is: {c}")
print("Execution finished", "\u2713")
# Out:
# Latest saved date of the file: 2026-03-31 11:23:14.223639 (2 seconds ago)
# The string representation is: 123
# Execution finished ✓

# %%
# test cell
def test_number_to_string() -> None:
    try:
        import number_to_string_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from number_to_string_solution import number_to_string
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [
        ((5,), "5"),
        ((2.5,), "2.5"),
        ((0,), "0"),
    ]

    for _in, _out in test_cases:
        _res = number_to_string(*_in)
        assert _res == _out

# %%
# validate the solution
solution_file = "number_to_string_solution.py"
test_file = "test_number_to_string.py"
export_cell_content("solution-3", solution_file)
export_cell_content("tests-3", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 11:23:14.223639 (11 seconds ago)
# Latest saved date of the file: 2026-03-31 11:23:14.223639 (11 seconds ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
#
# ############################################# coverage #############################################
#
# 1 passed in 0.09s
# Name                           Stmts   Miss Branch BrPart  Cover   Missing
# --------------------------------------------------------------------------
# number_to_string_solution.py       2      0      0      0   100%
# --------------------------------------------------------------------------
# TOTAL                              2      0      0      0   100%
# coverage True
#
#
# ############################################## flake8 ##############################################
# 0
# flake8 True
#
#
# ...

# %% [markdown]
# ## Problem 8
#
# Create a Python function called `format_temperature` that receives a float `t`
# and returns a string with `t` formatted using exactly two decimal places followed by `" °C"`.
#
# Example: `format_temperature(3.1)` returns `"3.10 °C"`.

# %%
# solution cell
def format_temperature(t: float) -> str:
    return f"{t:.2f} centigrade"

# %%
# %autoreload 2
# uncomment the line(s) below to debug
export_cell_content("solution-4", "format_temperature_solution.py")
from format_temperature_solution import format_temperature


t = 3.1
c = format_temperature(t)
print(f"The formatted temperature is: {c}")
print("Execution finished", "\u2713")
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
# test cell
def test_format_temperature() -> None:
    try:
        import format_temperature_solution
    except:
        raise ValueError("You did not execute your solution cell!")
    try:
        from format_temperature_solution import format_temperature
    except:
        raise ValueError("The module does not have the necessary function!")

    test_cases = [
        ((3.1,), "3.10 centigrade"),
        ((0.0,), "0.00 centigrade"),
        ((-5.555,), "-5.55 centigrade"),
    ]

    for _in, _out in test_cases:
        _res = format_temperature(*_in)
        assert _res == _out

# %%
# validate the solution
solution_file = "format_temperature_solution.py"
test_file = "test_format_temperature.py"
export_cell_content("solution-4", solution_file)
export_cell_content("tests-4", test_file)
passed = True

print('\n\033[0m')
print(" tests ".center(100, "#"))

# !coverage run -m pytest -q {test_file}
if _exit_code != 0:
    passed = False

print('\n\033[0m')
print(" coverage ".center(100, "#"))
# !coverage report -m {solution_file}
if _exit_code != 0:
    passed = False
print(f"coverage {passed}")

print('\n\033[0m')
print(" flake8 ".center(100, "#"))
# !flake8 {solution_file}
if _exit_code != 0:
    passed = False
print(f"flake8 {passed}")

print('\n\033[0m')
print(" pylint ".center(100, "#"))
# !pylint {solution_file}
if _exit_code != 0:
    passed = False
print(f"pylint {passed}")

print('\n\033[0m')
print(" mypy ".center(100, "#"))
# !mypy {solution_file}
if _exit_code != 0:
    passed = False
print(f"mypy {passed}")

print('\n\033[0m')
print(" isort ".center(100, "#"))
# !isort --check --diff {solution_file}
if _exit_code != 0:
    passed = False
print(f"isort {passed}")

print('\n\033[0m')
print(" result ".center(100, "#"))
if passed:
    print('\033[m tests passed', u'\u2713', "\033[0m")
else:
    raise AssertionError('\033[91m your code presented some issue, check messages '\
        'above', u'\u274C', "\033[0m")
# Out:
# Latest saved date of the file: 2026-03-31 11:23:14.223639 (28 seconds ago)
# Latest saved date of the file: 2026-03-31 11:23:14.223639 (28 seconds ago)
#
#
# ############################################## tests ###############################################
# .                                                                        [100%]
#
# ############################################# coverage #############################################
#
# 1 passed in 0.08s
# Name                             Stmts   Miss Branch BrPart  Cover   Missing
# ----------------------------------------------------------------------------
# format_temperature_solution.py       2      0      0      0   100%
# ----------------------------------------------------------------------------
# TOTAL                                2      0      0      0   100%
# coverage True
#
#
# ############################################## flake8 ##############################################
# 0
# flake8 True
#
#
# ...
